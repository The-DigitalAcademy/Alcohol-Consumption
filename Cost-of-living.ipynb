# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cost-of-living.csv')
df.head()
# Out:
#                                           Unnamed: 0  \
# 0                       Meal, Inexpensive Restaurant
# 1  Meal for 2 People, Mid-range Restaurant, Three...
# 2     McMeal at McDonalds (or Equivalent Combo Meal)
# 3                  Domestic Beer (0.5 liter draught)
# 4                  Imported Beer (0.33 liter bottle)
#
#    Saint Petersburg, Russia  Istanbul, Turkey  Izmir, Turkey  \
# 0                      7.34              4.58           3.06
# 1                     29.35             15.28          12.22
# 2                      4.40              3.82           3.06
# 3                      2.20              3.06           2.29
# 4                      2.20              3.06           2.75
#
#    Helsinki, Finland  Chisinau, Moldova  Milan, Italy  Cairo, Egypt  \
# 0              12.00               4.67          15.0          3.38
# 1              65.00              20.74          60.0         17.48
# 2               8.00               4.15           8.0          4.51
# 3               6.50               1.04           5.0          1.69
# 4               6.75               1.43           5.0          2.82
#
#    Banja Luka, Bosnia And Herzegovina  Baku, Azerbaijan  ...  Lviv, Ukraine  \
# 0                                3.58              5.27  ...           3.75
# 1                               22.99             23.73  ...          18.76
# 2                                3.58              4.22  ...           3.56
# 3                                1.02              0.84  ...           1.50
# 4                                1.53              2.11  ...           1.50
#
#    Novosibirsk, Russia  Bursa, Turkey  Brussels, Belgium  Jerusalem, Israel  \
# 0                 5.72           3.82               15.0              15.56
# 1                22.01          11.47               60.0              62.24
# 2                 3.67           3.06                8.2              12.97
# 3                 1.10           2.37                4.0               7.26
# 4                 2.20           3.06                4.0               7.26
#
#    Melbourne, Australia  Perth, Australia  Sydney, Australia  \
# 0                 10.22             12.43              11.81
# 1                 49.54             56.55              54.37
# 2                  7.12              7.32               7.15
# 3                  5.57              5.90               4.97
# 4                  5.57              5.59               4.97
#
#    Alexandria, Egypt  Quito, Ecuador
# 0               2.81            3.59
# 1              14.06           31.45
# 2               3.38            5.39
# 3               1.69            1.35
# 4               2.81            2.70
#
# [5 rows x 161 columns]

# %%
df = df.T

# %%
new_header = df.iloc[0]

# %%
df = df[1:]

# %%
df.columns = new_header

# %%
df['Total_cost'] = df.sum(axis=1)
# Out:
# /var/folders/lp/3qhm0mhn7zzb6hq5n93sfx400000gn/T/ipykernel_4696/2411597924.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Total_cost'] = df.sum(axis=1)

# %%
df = df.reset_index()

# %%
df.rename(columns  = {'index' : 'City'} , inplace = True)
df[['City' , 'Country' , 'other']] =df['City'].str.split(',', expand=True)

# %%
state = df[df.other == ' United States']['Country'].tolist()
df.Country = df.Country.apply(lambda x: 'United State' if x in state else x)
df.drop('other' , axis = 1 , inplace = True)

# %%
df_countries = df.groupby('Country')['Total_cost'].mean().reset_index().sort_values('Total_cost' ,axis=0, ascending=False, ignore_index=True )

# %%
df.head()
# Out:
# Unnamed: 0              City Meal, Inexpensive Restaurant  \
# 0           Saint Petersburg                         7.34
# 1                   Istanbul                         4.58
# 2                      Izmir                         3.06
# 3                   Helsinki                         12.0
# 4                   Chisinau                         4.67
#
# Unnamed: 0 Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                                       29.35
# 1                                                       15.28
# 2                                                       12.22
# 3                                                        65.0
# 4                                                       20.74
#
# Unnamed: 0 McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                                     4.4
# 1                                                    3.82
# 2                                                    3.06
# 3                                                     8.0
# 4                                                    4.15
#
# Unnamed: 0 Domestic Beer (0.5 liter draught)  \
# 0                                        2.2
# 1                                       3.06
# 2                                       2.29
# 3                                        6.5
# 4                                       1.04
#
# Unnamed: 0 Imported Beer (0.33 liter bottle) Coke/Pepsi (0.33 liter bottle)  \
# 0                                        2.2                           0.76
# 1                                       3.06                           0.64
# 2                                       2.75                           0.61
# 3                                       6.75                           2.66
# 4                                       1.43                           0.64
#
# Unnamed: 0 Water (0.33 liter bottle)  Milk (regular), (1 liter)  \
# 0                                0.53                      0.98
# 1                                0.24                      0.71
# 2                                0.22                      0.65
# 3                                1.89                      0.96
# 4                                0.44                      0.68
#
# Unnamed: 0 Loaf of Fresh White Bread (500g)  ... Rice (white), (1kg)  \
# 0                                      0.71  ...                0.92
# 1                                      0.36  ...                 1.3
# 2                                      0.38  ...                1.31
# 3                                      2.27  ...                2.13
# 4                                      0.33  ...                0.93
#
# Unnamed: 0 Tomato (1kg) Banana (1kg) Onion (1kg)  \
# 0                  1.91         0.89        0.48
# 1                   0.8         1.91        0.62
# 2                   0.7         1.78        0.58
# 3                  2.91         1.61        1.25
# 4                  1.56         1.37        0.59
#
# Unnamed: 0 Beef Round (1kg) (or Equivalent Back Leg Red Meat)  \
# 0                                                        7.18
# 1                                                        9.73
# 2                                                        8.61
# 3                                                       12.34
# 4                                                        5.37
#
# Unnamed: 0 Toyota Corolla 1.6l 97kW Comfort (Or Equivalent New Car)  \
# 0                                                    19305.29
# 1                                                    20874.72
# 2                                                    20898.83
# 3                                                    24402.77
# 4                                                    17238.13
#
# Unnamed: 0 Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child  \
# 0                                                      411.83
# 1                                                      282.94
# 2                                                      212.18
# 3                                                       351.6
# 4                                                      210.52
#
# Unnamed: 0 International Primary School, Yearly for 1 Child Total_cost  \
# 0                                                   5388.86   52116.33
# 1                                                   6905.43   56669.36
# 2                                                   4948.41   53544.69
# 3                                                    1641.0   67955.34
# 4                                                    2679.3   39955.80
#
# Unnamed: 0   Country
# 0             Russia
# 1             Turkey
# 2             Turkey
# 3            Finland
# 4            Moldova
#
# [5 rows x 58 columns]

# %%
df.drop(Unnamed:0)
# Out:
#   File "/var/folders/lp/3qhm0mhn7zzb6hq5n93sfx400000gn/T/ipykernel_4696/1673475205.py", line 1
#     df.drop(Unnamed:0)
#                    ^
# SyntaxError: invalid syntax

# %%
df = df.rename(columns={"Unnamed: 0": ""})
df.head()

# %%
df = df.set_index("").transpose().reset_index()
df.head()

# %%
df = df.rename(columns={"index":"Country_Capital"})
df[["Capital","Country"]] = df['Country_Capital'].str.rsplit(',',expand=True,n=1)
df.head()

# %%
country = df.groupby('Country').mean()
capital = df.groupby('Capital').mean()
country

# %%
df.info()

# %%
cols = list(df.columns)
cols = [cols[-1]] + cols[:-1]
df = df[cols]

# %%
df.head()
